# %%
path2004 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2004.txt"
path2005 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2005.txt"
path2006 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2006.txt"
path2007 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2007.txt"
path2008 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2008.txt"
path2009 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2009.txt"
path2010 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2010.txt"
path2011 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2011.txt"
path2012 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2012.txt"
path2013 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2013.txt"
path2014 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2014.txt"
path2015 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2015.txt"
path2016 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2016.txt"
path2017 = "C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/textminingfinal/2017.txt"

text2004 = open(path2004,'r',encoding='utf-8')
text2017 = open(path2017,'r',encoding='utf-8')

txt2004 = text2004.read().lower()
txt2017 = text2017.read().lower()

# %%
import pandas as pd

df = pd.read_csv("C:/Users/marko/OneDrive/바탕 화면/assignment/text mining/data csv.csv", index_col='words/year')

# df = df.reset_index(drop=True, inplace=True)

# df.set_index('words/year', inplace=True)

df[:11]
# Out:
#             2004  2005  2006  2007  2008  2009  2010  2011  2012  2013  2014  \
# words/year
# tokyo          2    22    27    57   101   141   176   140   164   352   456
# kyoto          0     3    16    26    36    47    77    46    62   110   175
# osaka          0     1     5    38    49    66    72    47    80   163   203
# yokohama       0     1     3     2     4     9     5     8     7     6    13
# hokkaido       0     0     2     4    12     5    18     8    11    22    35
# okinawa        0     0     0     0    67     5     5     4     2     2     4
# onsen          1     7    14    43    44    87    99    83   116   152   175
# ryokan         0     3    15   123   132   215   160   134   149   245   256
# temple         0    39    16   145   167   260   231   189   179   394   374
# shrine         0    28    12    72    80   116    83    68    65   142   146
# festival       1    25     8    34    48    83    60    58    70    94   156
#
#             2015  2016  2017
# ...

# %%
tokyo = df.loc['tokyo']
kyoto = df.loc['kyoto']
osaka = df.loc['osaka']
yokohama = df.loc['yokohama']
hokkaido = df.loc['hokkaido']
okinawa = df.loc['okinawa']
onsen = df.loc['onsen']
ryokan = df.loc['ryokan']
temple = df.loc['temple']
shrine = df.loc['shrine']
festival = df.loc['festival']

# %%
import matplotlib.pyplot as plt
import numpy as np

tokyo = df.loc['tokyo']
kyoto = df.loc['kyoto']
osaka = df.loc['osaka']
yokohama = df.loc['yokohama']
hokkaido = df.loc['hokkaido']
okinawa = df.loc['okinawa']


years = [2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017]
xpoints = np.array(years)

ytokyo = np.array(tokyo)
ykyoto = np.array(kyoto)
yosaka = np.array(osaka)
yyokohama = np.array(yokohama)
yhokkaido = np.array(hokkaido)
yokinawa = np.array(okinawa)

plt.plot(xpoints, ytokyo, label='Tokyo')
plt.plot(xpoints, yosaka, label='Osaka')
plt.plot(xpoints,ykyoto, label='Kyoto')
plt.plot(xpoints,yyokohama, label='Yokohama')
plt.plot(xpoints, yhokkaido, label='Hokkaido')
plt.plot(xpoints,yokinawa, label='Okinawa')

plt.legend()
plt.show()

# %%
ON = df.loc['onsen']
ryokan = df.loc['ryokan']
temple = df.loc['temple']
shrine = df.loc['shrine']
festival = df.loc['festival']

yonsen = np.array(ON)
yryokan = np.array(ryokan)
ytemple = np.array(temple)
yshrine = np.array(shrine)
yfestival = np.array(festival)


plt.plot(xpoints, ytemple, label='Temple')
plt.plot(xpoints,yryokan, label='Ryokan')
plt.plot(xpoints, yonsen, label='Onsen')
plt.plot(xpoints,yshrine, label='Shrine')
plt.plot(xpoints, yfestival, label='Festival')
plt.legend()
plt.show()
